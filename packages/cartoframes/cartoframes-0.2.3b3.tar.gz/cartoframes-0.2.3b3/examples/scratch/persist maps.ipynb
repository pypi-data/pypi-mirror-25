# %%
import pandas as pd
import cartoframes

import json

USERNAME = json.loads(open('credentials.json').read())['username']
APIKEY = json.loads(open('credentials.json').read())['api_key']

df = pd.read_carto(username=USERNAME,
                   api_key=APIKEY,
                   tablename='research_team')
# Out:
# Named map name: research_team_1489484675_236062

# %%
df.carto_map(persist=True)
# Out:
#     {
#       "version": "2.0.8",
#       "visualization": {
#         "name": "CARTOFRAMES PERSIST",
#         "description": null,
#         "version": 3,
#         "type": "derived",
#         "tags": [],
#         "privacy": "private",
#         "source": null,
#         "license": null,
#         "title": null,
#         "kind": "geom",
#         "attributions": null,
#         "bbox": null,
#         "display_name": null,
#         "map": {
#           "provider": "leaflet",
#           "bounding_box_sw": "[22.306233, -121.784928]",
#           "bounding_box_ne": "[55.944321, 73.188373]",
#           "center": "[16.819044,97.4866505]",
#           "zoom": 2,
#           "view_bounds_sw": "[22.306233, -121.784928]",
#           "view_bounds_ne": "[55.944321, 73.188373]",
#           "scrollwheel": false,
#           "legends": true,
#           "options": {
#             "legends": true,
#             "scrollwheel": false,
#             "layer_selector": false,
#             "dashboard_menu": true
#           }
#         },
#         "layers": [
#           {
#             "options": {
#               "type": "Tiled",
#               "urlTemplate": "https://{s}.tile.thunderforest.com/spinal-map/{z}/{x}/{y}.png",
#               "minZoom": 0,
#               "maxZoom": 21,
#               "name": "Custom basemap 60",
#               "className": "httpstileopenstreetmaporgzxypng",
#               "attribution": null,
#               "category": "Custom",
#               "tms": false,
#               "selected": true,
#               "val": "httpstileopenstreetmaporgzxypng",
#               "label": "Custom basemap 60",
#               "default": false,
#               "highlighted": true
#             },
#             "kind": "tiled",
#             "infowindow": null,
#             "tooltip": null,
#             "widgets": [],
#             "legends": []
#           },
#           {
#             "options": {
#               "opacity": 0.99,
#               "auto_bound": false,
#               "interactivity": "cartodb_id",
#               "debug": false,
#               "visible": true,
#               "tiler_domain": "carto.com",
#               "tiler_port": "443",
#               "tiler_protocol": "https",
#               "sql_domain": "carto.com",
#               "sql_port": "443",
#               "sql_protocol": "https",
#               "extra_params": {
#                 "cache_policy": "persist"
#               },
#               "cdn_url": "",
#               "tile_style_history": [],
#               "style_version": "2.1.1",
#               "table_name": "research_team",
#               "user_name": "eschbacher",
#               "type": "CartoDB",
#               "style_properties": {
#                 "type": "simple",
#                 "properties": {
#                   "fill": {
#                     "size": {
#                       "fixed": 7
#                     },
#                     "color": {
#                       "fixed": "#FFB927",
#                       "opacity": 0.9
#                     }
#                   },
#                   "stroke": {
#                     "size": {
#                       "fixed": 1
#                     },
#                     "color": {
#                       "fixed": "#FFF",
#                       "opacity": 1
#                     }
#                   },
#                   "blending": "none",
#                   "aggregation": {},
#                   "labels": {
#                     "enabled": false,
#                     "attribute": null,
#                     "font": "DejaVu Sans Book",
#                     "fill": {
#                       "size": {
#                         "fixed": 10
#                       },
#                       "color": {
#                         "fixed": "#FFFFFF",
#                         "opacity": 1
#                       }
#                     },
#                     "halo": {
#                       "size": {
#                         "fixed": 1
#                       },
#                       "color": {
#                         "fixed": "#6F808D",
#                         "opacity": 1
#                       }
#                     },
#                     "offset": -10,
#                     "overlap": true,
#                     "placement": "point"
#                   }
#                 }
#               },
#               "cartocss_history": [
#                 "#layer { marker-width: 7; marker-fill: #f00; marker-fill-opacity: 1; marker-allow-overlap: true; marker-line-width: 1; marker-line-color: #FFF; marker-line-opacity: 1; }"
#               ],
#               "sql_history": [
#                 "SELECT * FROM research_team"
#               ],
#               "source": "a0",
#               "letter": "a",
#               "color": "#66B79E",
#               "sql_wrap": null,
#               "tile_style": "#layer { marker-width: 7; marker-fill: #f00; marker-fill-opacity: 1; marker-allow-overlap: true; marker-line-width: 1; marker-line-color: #FFF; marker-line-opacity: 1; }",
#               "query": "SELECT * FROM research_team"
#             },
#             "kind": "carto",
#             "infowindow": {
#               "template_name": "none",
#               "fields": [],
#               "latlng": [
#                 0,
#                 0
#               ],
#               "offset": [
#                 28,
#                 0
#               ],
#               "maxHeight": 180,
#               "autoPan": true,
#               "template": "",
#               "content": "",
#               "visibility": false,
#               "alternative_names": {},
#               "width": 226,
#               "headerColor": {
#                 "color": {
#                   "fixed": "#35AAE5",
#                   "opacity": 1
#                 }
#               }
#             },
#             "tooltip": {
#               "fields": [],
#               "template_name": "none",
#               "vertical_offset": 0,
#               "horizontal_offset": 0,
#               "position": "top|center",
#               "template": "",
#               "template_type": "mustache"
#             },
#             "widgets": [],
#             "legends": []
#           }
#         ],
#         "overlays": [
#           {
#             "options": {
#               "display": true,
#               "x": 20,
#               "y": 20
#             },
#             "type": "share",
#             "template": ""
#           },
#           {
#             "options": {
#               "display": true,
#               "x": 60,
#               "y": 20
#             },
#             "type": "search",
#             "template": ""
#           },
#           {
#             "options": {
#               "display": true,
#               "x": 20,
#               "y": 20
#             },
#             "type": "zoom",
#             "template": "<a href='#zoom_in' class='zoom_in'>+</a> <a href='#zoom_out' class='zoom_out'>-</a>"
#           },
#           {
#             "options": {
#               "display": true,
#               "x": 20,
#               "y": 150
#             },
#             "type": "loader",
#             "template": "<div class='loader' original-title=''></div>"
#           },
#           {
#             "options": {
#               "display": true,
#               "x": 10,
#               "y": 40
#             },
#             "type": "logo",
#             "template": ""
#           }
#         ],
#         "analyses": [
#           {
#             "analysis_definition": {
#               "id": "a0",
#               "type": "source",
#               "params": {
#                 "query": "SELECT * FROM eschbacher.research_team"
#               },
#               "options": {
#                 "table_name": "eschbacher.research_team",
#                 "simple_geom": "point"
#               }
#             }
#           }
#         ],
#         "user": {
#           "username": "eschbacher"
#         },
#         "state": {
#           "json": {
#             "map": {
#               "ne": [
#                 55.944321,
#                 73.188373
#               ],
#               "sw": [
#                 22.306233,
#                 -121.784928
#               ]
#             }
#           }
#         }
#       }
#     }
#
# {"item_queue_id":"1ae86881-deb0-404d-b14a-354398ca4e7c","success":true}

# %%
import random
random.randint(0,9)
# Out:
# 3

# %%
import requests

queue_id = '1ae86881-deb0-404d-b14a-354398ca4e7c'
