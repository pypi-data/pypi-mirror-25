# %%
## Import your data from the Overpass API

import overpass
api = overpass.API(timeout=10000)
map_query = overpass.MapQuery(-136.4, 23.4, -59.2, 50.5)
response = api.Get('node[name="McDonald'"'"'s"];', responseformat="geojson")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bc5f551285dd> in <module>()
#       1 ## Import your data from the Overpass API
#       2
# ----> 3 import overpass
#       4 api = overpass.API(timeout=10000)
#       5 map_query = overpass.MapQuery(-136.4, 23.4, -59.2, 50.5)
#
# ModuleNotFoundError: No module named 'overpass'

# %%
print (response)
# Out:
# {"features": [{"geometry": {"coordinates": [-0.1316935, 51.5105308], "type": "Point"}, "id": 348865880, "properties": {"amenity": "fast_food", "cuisine": "chicken", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-7.1409258, 52.159652], "type": "Point"}, "id": 561242430, "properties": {"name": "Shake Shack", "shop": "confectionery"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9881353, 40.7415064], "type": "Point"}, "id": 1272605140, "properties": {"addr:housenumber": "11", "addr:postcode": "10010", "addr:street": "Madison Avenue", "amenity": "fast_food", "cuisine": "burger", "name": "Shake Shack", "opening_hours": "Mo-Su 11:00-23:00", "phone": "(212)889-6600", "website": "http://www.shakeshack.com/", "wheelchair": "yes", "wikipedia": "en:Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9765071, 40.7808586], "type": "Point"}, "id": 1888172061, "properties": {"addr:housenumber": "366", "addr:postcode": "10024", "addr:street": "Co
# ...

# %%
resp = {"features": [{"geometry": {"coordinates": [-0.1316935, 51.5105308], "type": "Point"}, "id": 348865880, "properties": {"amenity": "fast_food", "cuisine": "chicken", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-7.1409258, 52.159652], "type": "Point"}, "id": 561242430, "properties": {"name": "Shake Shack", "shop": "confectionery"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9881353, 40.7415064], "type": "Point"}, "id": 1272605140, "properties": {"addr:housenumber": "11", "addr:postcode": "10010", "addr:street": "Madison Avenue", "amenity": "fast_food", "cuisine": "burger", "name": "Shake Shack", "opening_hours": "Mo-Su 11:00-23:00", "phone": "(212)889-6600", "website": "http://www.shakeshack.com/", "wheelchair": "yes", "wikipedia": "en:Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9765071, 40.7808586], "type": "Point"}, "id": 1888172061, "properties": {"addr:housenumber": "366", "addr:postcode": "10024", "addr:street": "Columbus Avenue", "amenity": "restaurant", "cuisine": "burger", "internet_access": "wlan", "name": "Shake Shack", "website": "http://www.shakeshack.com/location/upper-west-side/", "wheelchair": "yes", "wheelchair_toilet": "no"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9890563, 40.7585044], "type": "Point"}, "id": 1899033656, "properties": {"addr:housenumber": "691", "addr:postcode": "10036", "addr:street": "8th Avenue", "amenity": "fast_food", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-74.0148288, 40.7152683], "type": "Point"}, "id": 1934501367, "properties": {"addr:city": "New York", "addr:housenumber": "215", "addr:postcode": "10282", "addr:state": "NY", "addr:street": "Murray Street", "amenity": "fast_food", "cuisine": "burger", "delivery": "no", "drive_through": "no", "name": "Shake Shack", "opening_hours": "Mon-Sun 11:00-23:00", "phone": "+1 646 545 4600", "smoking": "no", "takeaway": "yes", "website": "https://www.shakeshack.com/location/battery-park-city"}, "type": "Feature"}, {"geometry": {"coordinates": [-0.018892, 51.5047476], "type": "Point"}, "id": 1985574417, "properties": {"addr:city": "London", "addr:housename": "Park Pavilion", "addr:housenumber": "40", "addr:postcode": "E14 5FW", "addr:street": "Canada Square", "amenity": "fast_food", "cuisine": "burger", "level": "0", "name": "Shake Shack", "opening_hours": "Mo-Sa 11:00-23:00; Su 12:00-22:30", "website": "https://www.shakeshack.com/location/uk-london-canary-wharf"}, "type": "Feature"}, {"geometry": {"coordinates": [-77.041848, 38.906367], "type": "Point"}, "id": 2246967238, "properties": {"addr:city": "Washington", "addr:country": "US", "addr:housenumber": "1216", "addr:postcode": "20036", "addr:state": "DC", "addr:street": "18th Street Northwest", "amenity": "restaurant", "cuisine": "burger", "drive_in": "no", "level": "0", "name": "Shake Shack", "outdoor_seating": "yes", "smoking": "no", "takeaway": "yes", "website": "http://www.shakeshack.com/location/dupont-circle/", "wheelchair": "yes"}, "type": "Feature"}, {"geometry": {"coordinates": [-77.0237893, 38.8970578], "type": "Point"}, "id": 2419110687, "properties": {"addr:city": "Washington", "addr:housenumber": "800", "addr:street": "F Street Northwest", "amenity": "fast_food", "cuisine": "burger", "drive_through": "no", "name": "Shake Shack", "smoking": "no", "takeaway": "yes"}, "type": "Feature"}, {"geometry": {"coordinates": [-0.1225568, 51.5117522], "type": "Point"}, "id": 2526585882, "properties": {"addr:city": "London", "addr:country": "GB", "addr:housename": "Market Building", "addr:housenumber": "24", "addr:postcode": "WC2E 8RD", "addr:street": "Covent Garden Piazza", "amenity": "fast_food", "contact:phone": "+44 20 35981360", "cuisine": "burger", "name": "Shake Shack", "opening_hours": "Mo-Sa 11:00-23:00; Su 11:00-22:30", "takeaway": "yes", "wheelchair": "limited"}, "type": "Feature"}, {"geometry": {"coordinates": [37.5882813, 55.7486066], "type": "Point"}, "id": 2586573777, "properties": {"amenity": "fast_food", "contact:phone": "+7 499 2528399", "contact:website": "http://www.shakeshack.com", "cuisine": "burger", "name": "Shake Shack", "opening_hours": "Mo-Su 10:00-23:00"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9886262, 40.6921442], "type": "Point"}, "id": 2596227488, "properties": {"addr:housenumber": "409", "addr:postcode": "11201", "addr:street": "Fulton Street", "amenity": "fast_food", "cuisine": "burger", "name": "Shake Shack", "name:fr": "Burger", "phone": "+1 718 307-7590"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9549257, 40.779013], "type": "Point"}, "id": 2620513892, "properties": {"addr:city": "New York", "addr:country": "US", "addr:housenumber": "154", "addr:postcode": "10028", "addr:state": "NY", "addr:street": "East 86th Street", "amenity": "fast_food", "cuisine": "burger", "email": "ues@shakeshack.com", "name": "Shake Shack", "opening_hours": "Mo-Su 11:00-23:00"}, "type": "Feature"}, {"geometry": {"coordinates": [-75.1884746, 39.9538151], "type": "Point"}, "id": 2699432051, "properties": {"amenity": "fast_food", "name": "Shake Shack", "wheelchair": "yes"}, "type": "Feature"}, {"geometry": {"coordinates": [-72.9283945, 41.307009], "type": "Point"}, "id": 2760039198, "properties": {"amenity": "fast_food", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [55.13168, 25.077087], "type": "Point"}, "id": 2826539801, "properties": {"amenity": "restaurant", "brand": "Shale Shack", "name": "Shake Shack", "source": "Site survey", "wheelchair": "yes"}, "type": "Feature"}, {"geometry": {"coordinates": [-75.173792, 39.9512405], "type": "Point"}, "id": 2910156409, "properties": {"addr:city": "Philadelphia", "addr:housenumber": "2000", "addr:postcode": "19103", "addr:street": "Sansom Street", "amenity": "restaurant", "cuisine": "burger", "name": "Shake Shack", "opening_hours": "11:00-23:00", "phone": "+1 215 809 1742", "smoking": "no", "website": "http://www.shakeshack.com/location/philadelphia/"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9940577, 40.703039], "type": "Point"}, "id": 3174844884, "properties": {"addr:city": "Brooklyn", "addr:housenumber": "1", "addr:postcode": "11201", "addr:state": "NY", "addr:street": "Old Fulton Street", "amenity": "restaurant", "cuisine": "burger", "name": "Shake Shack", "smoking": "no", "source": "survey", "takeaway": "yes"}, "type": "Feature"}, {"geometry": {"coordinates": [39.1677791, 21.5538532], "type": "Point"}, "id": 3301858009, "properties": {"amenity": "restaurant", "cuisine": "burger", "name": "Shake Shack", "name:en": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [5.4471895, 43.5291622], "type": "Point"}, "id": 3356510515, "properties": {"addr:city": "Aix-en-Provence", "addr:postcode": "13100", "addr:street": "Rue des marseillais", "amenity": "fast_food", "cuisine": "pizza", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [28.9747975, 41.0286694], "type": "Point"}, "id": 3453817696, "properties": {"amenity": "fast_food", "cuisine": "burger", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-87.6256661, 41.8926777], "type": "Point"}, "id": 3575167248, "properties": {"amenity": "fast_food", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-1.6848687, 53.8536381], "type": "Point"}, "id": 3715292792, "properties": {"addr:city": "Rawdon", "addr:housenumber": "5", "addr:postcode": "LS19 6HW", "addr:street": "Harrogate Road", "amenity": "cafe", "fhrs:id": "778661", "name": "Shake Shack", "phone": "01132 505414", "website": "http://www.supershakeshack.com/"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9756547, 40.7494619], "type": "Point"}, "id": 3830892127, "properties": {"amenity": "fast_food", "cuisine": "burger", "name": "Shake Shack", "website": "https://www.shakeshack.com"}, "type": "Feature"}, {"geometry": {"coordinates": [54.6081173, 24.490441], "type": "Point"}, "id": 3842546742, "properties": {"addr:city": "Abu Dhabi", "addr:country": "AE", "addr:place": "Yas Mall", "addr:street": "Yas Leisure Drive", "amenity": "restaurant", "cuisine": "burger", "name": "Shake Shack", "smoking": "no"}, "type": "Feature"}, {"geometry": {"coordinates": [-97.725794, 30.399031], "type": "Point"}, "id": 3864130778, "properties": {"addr:housenumber": "11228", "addr:postcode": "78758", "addr:street": "Domain Drive", "amenity": "restaurant", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-87.6247026, 41.8816017], "type": "Point"}, "id": 3889639803, "properties": {"addr:city": "Chicago", "addr:housenumber": "12", "addr:street": "South Michigan Avenue", "amenity": "fast_food", "cuisine": "burger", "delivery": "no", "drive_through": "no", "name": "Shake Shack", "smoking": "no", "takeaway": "yes"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.2991157, 41.1385191], "type": "Point"}, "id": 3957307759, "properties": {"addr:city": "Westport", "addr:housenumber": "1849", "addr:postcode": "06880", "addr:state": "CT", "addr:street": "Post Road East", "amenity": "restaurant", "cuisine": "burger", "name": "Shake Shack", "opening_hours": "Su-Th 11:00-22:00; Fr-Sa 11:00-23:00", "takeaway": "yes", "website": "https://www.shakeshack.com/location/westport/"}, "type": "Feature"}, {"geometry": {"coordinates": [139.7198036, 35.6733693], "type": "Point"}, "id": 3997300427, "properties": {"amenity": "restaurant", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9775547, 40.7528125], "type": "Point"}, "id": 4035588419, "properties": {"amenity": "fast_food", "level": "-1", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.783284, 40.642507], "type": "Point"}, "id": 4109967906, "properties": {"amenity": "fast_food", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [139.7093941, 35.6466153], "type": "Point"}, "id": 4231510742, "properties": {"amenity": "fast_food", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-0.1280249, 51.5168459], "type": "Point"}, "id": 4259375230, "properties": {"addr:city": "London", "addr:housenumber": "80", "addr:postcode": "WC1A 1HB", "addr:street": "New Oxford Street", "amenity": "fast_food", "cuisine": "burger", "level": "0", "name": "Shake Shack", "opening_hours": "Mo-Sa 11:00-23:00; Su 11:00-21:00", "phone": "01925 555 171", "website": "https://www.shakeshack.com"}, "type": "Feature"}, {"geometry": {"coordinates": [37.5327239, 55.7905089], "type": "Point"}, "id": 4285863789, "properties": {"amenity": "fast_food", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9754629, 40.7488718], "type": "Point"}, "id": 4300001393, "properties": {"addr:housenumber": "600", "addr:postcode": "10016", "amenity": "fast_food", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-73.9878729, 40.7511283], "type": "Point"}, "id": 4300001394, "properties": {"amenity": "fast_food", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-115.1736405, 36.1030802], "type": "Point"}, "id": 4352067391, "properties": {"addr:street": "South Las Vegas Boulevard", "amenity": "fast_food", "internet_access": "wlan", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-96.8030313, 32.793558], "type": "Point"}, "id": 4491434808, "properties": {"amenity": "restaurant", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-80.1400814, 25.7910188], "type": "Point"}, "id": 4499033889, "properties": {"amenity": "restaurant", "name": "Shake Shack", "name:en": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-71.1209682, 42.3722375], "type": "Point"}, "id": 4549551449, "properties": {"addr:city": "Cambridge", "addr:housenumber": "92", "addr:postcode": "02138", "addr:state": "MA", "addr:street": "Winthrop Street", "amenity": "fast_food", "cuisine": "burger", "delivery": "no", "drive_through": "no", "name": "Shake Shack", "opening_hours": "11:00-23:00", "phone": "+16177588495", "takeaway": "yes", "toilets": "yes", "toilets:access": "customers", "website": "https://www.shakeshack.com/location/harvard-square/", "wheelchair": "yes"}, "type": "Feature"}, {"geometry": {"coordinates": [-84.3809139, 33.8376624], "type": "Point"}, "id": 4664879371, "properties": {"addr:city": "Atlanta", "addr:housenumber": "3035", "addr:postcode": "30305", "addr:state": "GA", "addr:street": "Peachtree Road", "amenity": "restaurant", "cuisine": "burger", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-83.0460237, 42.3310799], "type": "Point"}, "id": 4701462959, "properties": {"addr:city": "Detroit", "addr:housenumber": "660", "addr:postcode": "48226", "addr:state": "MI", "addr:street": "Woodward Avenue", "amenity": "fast_food", "delivery": "no", "drive_through": "no", "name": "Shake Shack", "opening_hours": "11:00-21:30", "outdoor_seating": "no", "smoking": "no", "takeaway": "yes"}, "type": "Feature"}, {"geometry": {"coordinates": [-76.6098127, 39.2869029], "type": "Point"}, "id": 4710414576, "properties": {"amenity": "restaurant", "contact:website": "https://www.shakeshack.com/location/inner-harbor-baltimore/", "cuisine": "burger", "level": "0", "name": "Shake Shack", "opening_hours": "Su-Th 11:00-22:00; Fr-Sa 11:00-23:00", "outdoor_seating": "yes", "takeaway": "yes", "toilets": "customers", "toilets:wheelchair": "yes", "wheelchair": "yes"}, "type": "Feature"}, {"geometry": {"coordinates": [-115.0854223, 36.0215891], "type": "Point"}, "id": 4742179545, "properties": {"amenity": "restaurant", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-104.9808456, 39.7622767], "type": "Point"}, "id": 4802755228, "properties": {"amenity": "restaurant", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-77.006293, 38.8735146], "type": "Point"}, "id": 4846520504, "properties": {"amenity": "fast_food", "name": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-118.3773346, 34.0886098], "type": "Point"}, "id": 4903112334, "properties": {"amenity": "cafe", "cuisine": "burger", "name": "Shake Shack", "name:en": "Shake Shack"}, "type": "Feature"}, {"geometry": {"coordinates": [-77.0069077, 38.8766984], "type": "Point"}, "id": 4913903121, "properties": {"amenity": "fast_food", "name": "Shake Shack", "name:en": "Shake Shack"}, "type": "Feature"}], "type": "FeatureCollection"}

# %%
## Import CARTO Frames and Pandas

import cartoframes
from cartoframes.credentials import set_credentials
import pandas as pd

# BASEURL are in the format:
#  https://USERNAME.carto.com  -- for all cloud users, even if in a multiuser organization
#  for on premise installs, contact your admin
BASEURL = 'https://eschbacher.carto.com' # <-- replace with your username 
APIKEY = '7db1d0957a6f4a10c9ab8bd437ed6b3e28b3d960' # <-- your CARTO API key
set_credentials(base_url=BASEURL, api_key=APIKEY, overwrite=True)

cc = cartoframes.CartoContext()

# %%
## Unpack the geojson file

import geopandas as gpd

gdf = gpd.GeoDataFrame.from_features(resp['features'])
gdf.head()
# Out:
#   addr:city addr:country addr:housename addr:housenumber addr:place  \
# 0       NaN          NaN            NaN              NaN        NaN
# 1       NaN          NaN            NaN              NaN        NaN
# 2       NaN          NaN            NaN               11        NaN
# 3       NaN          NaN            NaN              366        NaN
# 4       NaN          NaN            NaN              691        NaN
#
#   addr:postcode addr:state      addr:street     amenity brand       ...        \
# 0           NaN        NaN              NaN   fast_food   NaN       ...
# 1           NaN        NaN              NaN         NaN   NaN       ...
# 2         10010        NaN   Madison Avenue   fast_food   NaN       ...
# 3         10024        NaN  Columbus Avenue  restaurant   NaN       ...
# 4         10036        NaN       8th Avenue   fast_food   NaN       ...
#
#   smoking source takeaway toilets toilets:access toilets:wheelchair  \
# ...

# %%
## Designate a table name and push to CARTO

cc_table = 'matts_new_table'

# cc = cartoframes.CartoContext(BASEURL, APIKEY)
# cc.write(gdf, cc_table)

# %%
# Get a CARTO table as a pandas DataFrame

df = cc.read(cc_table)
df.head(1)
# Out:
#                                                      the_geom  \
# cartodb_id
# 1           0101000020E61000006342CC2555DBC0BFE4CCC01259C1...
#
#                                          the_geom_webmercator field_1  \
# cartodb_id
# 1           0101000020110F000024B586D406A2CCC063FB529CC99A...       0
#
#            addr_city addr_country addr_housename addr_housenumber addr_place  \
# cartodb_id
# 1
#
#            addr_postcode addr_state    ...    smoking source takeaway toilets  \
# cartodb_id                             ...
# 1                                      ...
#
#            toilets_access toilets_wheelchair website wheelchair  \
# cartodb_id
# 1
#
#            wheelchair_toilet wikipedia
# cartodb_id
# 1
#
# [1 rows x 40 columns]

# %%
## Create map in CARTO

from cartoframes import Layer, styling
l = Layer(cc_table, color={'column': 'amenity', 'scheme': styling.vivid(7)})
cc.map(layers=l, interactive=True)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html>
#   <head>
#     <title>Carto</title>
#     <meta name='viewport' content='initial-scale=1.0, user-scalable=no' />
#     <meta http-equiv='content-type' content='text/html; charset=UTF-8' />
#     <link rel='shortcut icon' href='http://cartodb.com/assets/favicon.ico' />
#
#     <style>
#      html, body, #map {
#        height: 100%;
#        padding: 0;
#        margin: 0;
#      }
#      #zoom-center {
#        position: absolute;
#        right: 0;
#        top: 0;
#        background-color: rgba(255, 255, 255, 0.7);
#        width: 240px;
#        z-index: 100;
#        padding: 4px;
#      }
#     </style>
#
#     <link rel='stylesheet' href='https://cartodb-libs.global.ssl.fastly.net/cartodb.js/v3/3.15/themes/css/cartodb.css' />
#   </head>
#   <body>
#     <div id='zoom-center'>
#       zoom=<span id='zoom'>4</span>,
#       lng=<span id='lon'>No data</span>, lat=<span id='lat'>No data</span></div>
#     <div id='map'></div>
# ...
