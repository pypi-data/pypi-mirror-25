# %% [markdown]
# ## cartoframes: Augmenting from the Data Obs

# %%
import pandas as pd
import cartoframes
USERNAME = 'eschbacher'
APIKEY = '8e92c06c9a91f8d3c00455109e8e609ee4096d62'
df = pd.read_carto(username=USERNAME,
                   api_key=APIKEY,
                   tablename='brooklyn_poverty_notnull_geoms')
df.head()
# Out:
# Named map name: brooklyn_poverty_notnull_geoms_1489164719_11731
#                    geoid  high_school_diploma_2011_2015  \
# cartodb_id
# 2           360470050003                       0.149158
# 3           360470108003                       0.205291
# 4           360470110001                       0.199651
# 5           360470122001                       0.157618
# 6           360470129012                       0.057947
#
#             median_income_2011_2015  poverty_2011_2015  poverty_count  \
# cartodb_id
# 2                      90018.474450           0.042093      23.112583
# 3                      32181.247826           0.380668     818.804124
# 4                      40238.563679           0.288949     237.985714
# 5                      36365.794472           0.383904     908.259494
# 6                      81931.612998           0.112196      57.217391
#
#             poverty_per_pop  \
# cartodb_id
# 2                  0.031191
# 3                  0.396132
# 4                  0.182225
# 5                  0.426613
# 6                  0.050059
#
#                                                      the_geom  \
# cartodb_id
# 2           0103000020E6100000010000002E000000AE3BD7DE5982...
# 3           0103000020E610000001000000330000000DEB728F6A80...
# 4           0103000020E61000000100000037000000EAF335C4AF7F...
# 5           0103000020E610000001000000280000000C119FF02D81...
# 6           0103000020E6100000010000002900000015994303B97E...
#
#                                          the_geom_webmercator  \
# cartodb_id
# 2           0103000020110F0000010000002E000000E50CD0EA9070...
# 3           0103000020110F00000100000033000000AA364995476D...
# 4           0103000020110F00000100000037000000217E7F4B0A6C...
# 5           0103000020110F000001000000280000003F8F7C74936E...
# 6           0103000020110F00000100000029000000B579AF28676A...
#
#             total_pop_2011_2015  total_population
# cartodb_id
# 2                   3348.574634             741.0
# 3                  28410.943088            2067.0
# 4                  17049.633900            1306.0
# 5                  31419.244144            2129.0
# 6                  18834.917064            1143.0

# %%
df.carto_map(interactive=True, color={'colname': 'poverty_per_pop'})
# Out:
# <iframe src="https://cdn.rawgit.com/andy-esch/6d993d3f25c5856ea38d1f374e57722e/raw/ce30379f35aafd027816f065b4e5c52f881c4a86/index.html?username=eschbacher&tablename=brooklyn_poverty_notnull_geoms&cartocss=%23layer+%7B+polygon-fill%3A+ramp%28%5Bpoverty_per_pop%5D%2C+cartocolor%28RedOr%29%2C+quantiles%28%29%29%3B+line-width%3A+0.5%3B+line-color%3A+%23FFF%3B+line-opacity%3A+0.5%3B+%7D&basemap=None&bounds=40.7391679594665%2C-73.8334120112118%2C40.5695860392157%2C-74.0419259959785&q=%257B%250A%2520%2520%2520%2520%2520%2520%2522user_name%2522%253A%2520%2522eschbacher%2522%252C%250A%2520%2520%2520%2520%2520%2520%2522type%2522%253A%2520%2522namedmap%2522%252C%250A%2520%2520%2520%2520%2520%2520%2522named_map%2522%253A%2520%257B%250A%2520%2520%2520%2520%2520%2520%2520%2520%2522name%2522%253A%2520%2522brooklyn_poverty_notnull_geoms_1489164719_11731%2522%250A%2520%2520%2520%2520%2520%2520%257D%252C%250A%2520%2520%2520%2520%2520%2520%2522subdomains%2522%253A%2520%255B%2520%2522a%2522%252C%2520%2522b%2522%252C%2520%2522c%2522%2520%255D%250A%2520%2520%2520%2520%2520%2520%257D" width=647 height=400>Preview image: <img src="http://eschbacher.carto.com/api/v1/map/static/named/brooklyn_poverty_notnull_geoms_1489164719_11731/647/400.png" /></iframe>

# %%
# total pop, high school diploma (normalized), median income, poverty status (normalized)
# TODO: add optional_colname
# TODO: aggregate points in polys given extent (using do boundaries of specified levels)
data_obs_measures = [{'numer_id': 'us.census.acs.B01003001'},
                     {'numer_id': 'us.census.acs.B15003017', 'denominator': 'predenominated'},
                     {'numer_id': 'us.census.acs.B19013001'},
                     {'numer_id': 'us.census.acs.B17001002', 'denominator': 'predenominated'}]
df.carto_do_augment(data_obs_measures)
df.head(10)
# Out:
#                    geoid  poverty_count  poverty_per_pop  \
# cartodb_id
# 153         360470018001            NaN              NaN
# 946         360470352001     649.600000         0.641264
# 15          360470514002     574.101597         0.325824
# 37          360470137001      67.453521         0.078709
# 1           360470043001       0.000000              NaN
# 2           360470050003      23.112583         0.031191
# 3           360470108003     818.804124         0.396132
# 4           360470110001     237.985714         0.182225
# 5           360470122001     908.259494         0.426613
# 6           360470129012      57.217391         0.050059
#
#                                                      the_geom  \
# cartodb_id
# 153         0103000020E61000000100000061030000074700141282...
# 946         0103000020E6100000010000002F0200009F3510EC2680...
# 15          0103000020E610000001000000270000003EA02C14AB7D...
# 37          0103000020E61000000100000027000000113ACE5D267F...
# 1           0103000020E61000000100000029000000F46F21D1657F...
# 2           0103000020E6100000010000002E000000AE3BD7DE5982...
# 3           0103000020E610000001000000330000000DEB728F6A80...
# 4           0103000020E61000000100000037000000EAF335C4AF7F...
# 5           0103000020E610000001000000280000000C119FF02D81...
# 6           0103000020E6100000010000002900000015994303B97E...
#
#                                          the_geom_webmercator  \
# cartodb_id
# 153         0103000020110F00000100000061030000640B81F81670...
# 946         0103000020110F0000010000002F020000E9745CB1D46C...
# 15          0103000020110F00000100000027000000394022A69C68...
# 37          0103000020110F0000010000002700000096343BE8206B...
# 1           0103000020110F00000100000029000000F04427AF8C6B...
# 2           0103000020110F0000010000002E000000E50CD0EA9070...
# 3           0103000020110F00000100000033000000AA364995476D...
# 4           0103000020110F00000100000037000000217E7F4B0A6C...
# 5           0103000020110F000001000000280000003F8F7C74936E...
# 6           0103000020110F00000100000029000000B579AF28676A...
#
#             total_population  high_school_diploma_2011_2015  \
# cartodb_id
# 153                   2206.0                       0.219213
# 946                   1013.0                       0.258464
# 15                    1762.0                       0.264986
# 37                     857.0                       0.105692
# 1                      140.0                       0.059511
# 2                      741.0                       0.149158
# 3                     2067.0                       0.205291
# 4                     1306.0                       0.199651
# 5                     2129.0                       0.157618
# 6                     1143.0                       0.057947
#
#             median_income_2011_2015  poverty_2011_2015  total_pop_2011_2015
# cartodb_id
# 153                    36414.226756           0.305719          1800.959283
# 946                    17156.148349           0.413366          3592.675275
# 15                     45746.135380           0.162936         39895.093066
# 37                    100039.579057           0.149699         21497.117857
# 1                     112115.160834           0.086910         19340.257651
# 2                      90018.474450           0.042093          3348.574634
# 3                      32181.247826           0.380668         28410.943088
# 4                      40238.563679           0.288949         17049.633900
# 5                      36365.794472           0.383904         31419.244144
# 6                      81931.612998           0.112196         18834.917064

# %%
df.carto_map(interactive=True, 
             color={'colname': 'high_school_diploma_2011_2015', 'ramp': 'Mint'},
             debug=True)
# Out:
# #layer { polygon-fill: ramp([high_school_diploma_2011_2015], cartocolor(Mint), quantiles()); line-width: 0.5; line-color: #FFF; line-opacity: 0.5; }
# /files/cartoframes.html?username=eschbacher&tablename=brooklyn_poverty_notnull_geoms&cartocss=%23layer+%7B+polygon-fill%3A+ramp%28%5Bhigh_school_diploma_2011_2015%5D%2C+cartocolor%28Mint%29%2C+quantiles%28%29%29%3B+line-width%3A+0.5%3B+line-color%3A+%23FFF%3B+line-opacity%3A+0.5%3B+%7D&basemap=None&bounds=40.7391679594665%2C-73.8334120112118%2C40.5695860392157%2C-74.0419259959785&q=%257B%250A%2520%2520%2520%2520%2520%2520%2522user_name%2522%253A%2520%2522eschbacher%2522%252C%250A%2520%2520%2520%2520%2520%2520%2522type%2522%253A%2520%2522namedmap%2522%252C%250A%2520%2520%2520%2520%2520%2520%2522named_map%2522%253A%2520%257B%250A%2520%2520%2520%2520%2520%2520%2520%2520%2522name%2522%253A%2520%2522brooklyn_poverty_notnull_geoms_1489163766_249506%2522%250A%2520%2520%2520%2520%2520%2520%257D%252C%250A%2520%2520%2520%2520%2520%2520%2522subdomains%2522%253A%2520%255B%2520%2522a%2522%252C%2520%2522b%2522%252C%2520%2522c%2522%2520%255D%250A%2520%2520%2520%2520%2520%2520%257D
# <iframe src="/files/cartoframes.html?username=eschbacher&tablename=brooklyn_poverty_notnull_geoms&cartocss=%23layer+%7B+polygon-fill%3A+ramp%28%5Bhigh_school_diploma_2011_2015%5D%2C+cartocolor%28Mint%29%2C+quantiles%28%29%29%3B+line-width%3A+0.5%3B+line-color%3A+%23FFF%3B+line-opacity%3A+0.5%3B+%7D&basemap=None&bounds=40.7391679594665%2C-73.8334120112118%2C40.5695860392157%2C-74.0419259959785&q=%257B%250A%2520%2520%2520%2520%2520%2520%2522user_name%2522%253A%2520%2522eschbacher%2522%252C%250A%2520%2520%2520%2520%2520%2520%2522type%2522%253A%2520%2522namedmap%2522%252C%250A%2520%2520%2520%2520%2520%2520%2522named_map%2522%253A%2520%257B%250A%2520%2520%2520%2520%2520%2520%2520%2520%2522name%2522%253A%2520%2522brooklyn_poverty_notnull_geoms_1489163766_249506%2522%250A%2520%2520%2520%2520%2520%2520%257D%252C%250A%2520%2520%2520%2520%2520%2520%2522subdomains%2522%253A%2520%255B%2520%2522a%2522%252C%2520%2522b%2522%252C%2520%2522c%2522%2520%255D%250A%2520%2520%2520%2520%2520%2520%257D" width=647 height=400>Preview image: <img src="http://eschbacher.carto.com/api/v1/map/static/named/brooklyn_poverty_notnull_geoms_1489163766_249506/647/400.png" /></iframe>

# %%
import pandas as pd
import cartoframes
USERNAME = 'eschbacher'
APIKEY = '8e92c06c9a91f8d3c00455109e8e609ee4096d62'
df = pd.read_carto(username=USERNAME,
                   api_key=APIKEY,
                   query='',
                   tablename='test_table')
df.head()
